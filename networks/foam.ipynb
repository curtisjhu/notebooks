# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # Mimicking how Soap Bubbles subdivide
#
# Intuitively I can try an approach like voronoi diagrams. But this attempts to create uniformly sized groups.

# %%
G = nx.fast_gnp_random_graph(n=20, p=0.5)

nx.draw(G, with_labels=True)

# %% [markdown]
# # Mimicking how Soap Bubbles pop when too big
